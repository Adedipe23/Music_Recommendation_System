# %% [markdown]
# # Resonance — exploratory analysis
# Inspect the active artist-listening dataset and its interaction distribution.

# %%
from src.data_loader import load_interactions
interactions, source = load_interactions()
source, interactions.describe(include='all')

# %%
interactions.groupby('artist_name').agg(total_plays=('play_count', 'sum'), listeners=('user_id', 'nunique')).nlargest(20, 'total_plays')
